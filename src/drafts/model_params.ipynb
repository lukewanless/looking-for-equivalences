# %%
from lr.models.transformers.BertWrapper import BertWrapper
from lr.models.transformers.RobertaWrapper import RobertaWrapper
from lr.models.transformers.AlbertWrapper import AlbertWrapper
from lr.models.transformers.XLNetWrapper import XLNetWrapper

# %%
hyperparams_bert = {"local_rank": -1,
               "overwrite_cache": False,
               "per_gpu_train_batch_size": 32,
               "per_gpu_eval_batch_size": 50,
               "gradient_accumulation_steps": 1,
               "max_seq_length":130,
               "max_steps": -1,
               "warmup_steps": 0,
               "no_cuda": False,
               "n_gpu": 1,
               "model_name_or_path": "bert",
               "fp16": False,
               "fp16_opt_level": "01",
               "device": "cpu",
               "verbose": True,
               "model_type": "bert",
               "pad_on_left": False,
               "pad_token": 0,
               'eval_sample_size': 200,
               "pad_token_segment_id": 0,
               "random_state": 1313,
               "base_path":"dfsfs",
               "pretrained_weights": 'bert-base-uncased',
               "mask_padding_with_zero": True}

hyperparams_roberta = {"local_rank": -1,
               "overwrite_cache": False,
               "per_gpu_train_batch_size": 32,
               "per_gpu_eval_batch_size": 50,
               "gradient_accumulation_steps": 1,
               "max_seq_length":140,
               "max_steps": -1,
               "warmup_steps": 0,
               "no_cuda": False,
               "n_gpu": 1,
               "model_name_or_path": "bert",
               "fp16": False,
               "fp16_opt_level": "01",
               "device": "cpu",
               "verbose": True,
               "model_type": "bert",
               "pad_on_left": False,
               "pad_token": 0,
               'eval_sample_size': 200,
               "pad_token_segment_id": 0,
               "random_state": 1313,
               "base_path":"dfsfs",
               "pretrained_weights": 'roberta-base',
               "mask_padding_with_zero": True}

hyperparams_albert = {"local_rank": -1,
               "overwrite_cache": False,
               "per_gpu_train_batch_size": 32,
               "per_gpu_eval_batch_size": 50,
               "gradient_accumulation_steps": 1,
               "max_seq_length":140,
               "max_steps": -1,
               "warmup_steps": 0,
               "no_cuda": False,
               "n_gpu": 1,
               "model_name_or_path": "bert",
               "fp16": False,
               "fp16_opt_level": "01",
               "device": "cpu",
               "verbose": True,
               "model_type": "bert",
               "pad_on_left": False,
               "pad_token": 0,
               'eval_sample_size': 200,
               "pad_token_segment_id": 0,
               "random_state": 1313,
               "base_path":"dfsfs",
               "pretrained_weights": 'albert-base-v2',
               "mask_padding_with_zero": True}

hyperparams_xlnet = {"local_rank": -1,
               "overwrite_cache": False,
               "per_gpu_train_batch_size": 32,
               "per_gpu_eval_batch_size": 50,
               "gradient_accumulation_steps": 1,
               "max_seq_length":140,
               "max_steps": -1,
               "warmup_steps": 0,
               "no_cuda": False,
               "n_gpu": 1,
               "model_name_or_path": "bert",
               "fp16": False,
               "fp16_opt_level": "01",
               "device": "cpu",
               "verbose": True,
               "model_type": "bert",
               "pad_on_left": False,
               "pad_token": 0,
               'eval_sample_size': 200,
               "pad_token_segment_id": 0,
               "random_state": 1313,
               "base_path":"dfsfs",
               "pretrained_weights": 'xlnet-base-cased',
               "mask_padding_with_zero": True}


bert = BertWrapper(hyperparams_bert)
roberta = RobertaWrapper(hyperparams_roberta)
albert = AlbertWrapper(hyperparams_albert)
xlnet = XLNetWrapper(hyperparams_xlnet)


print("BERT params = {}".format(bert.get_param_count()))
print("RoBERTa params = {}".format(roberta.get_param_count()))
print("ALBERT params = {}".format(albert.get_param_count()))
print("XLNET params = {}".format(xlnet.get_param_count()))
# Out:
# BERT params = 109484547
# RoBERTa params = 125238531
# ALBERT params = 11685891
# XLNET params = 117311235
