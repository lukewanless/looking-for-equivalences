# %% [markdown]
# # Qualitative Analysis 4

# %%
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from IPython.display import display, HTML, Markdown
from lr.text_processing.util import pre_process_nli_df
from collections import Counter
from lr.stats.h_testing import get_paired_t_statistic

# %% [markdown]
# ## When $\rho=1$ which test examples are affected by the transformation?

# %%
m_name = "roberta_large"
data = "mnli"
batch = 1
path = "raw_results/{}/{}/syn_p_h/batch{}/rho_1p00_results.csv".format(data, m_name, batch)
df = pd.read_csv(path)

snli_trans = pd.read_csv("data/{}/test_p_h_syn_noun.csv".format(data))
sin_noun = pd.read_csv("data/{}/syn_noun.csv".format(data))
key2id = {k:i for k,i in zip(sin_noun.key,sin_noun.index)}
f = lambda k: key2id[k]

# %%
def filter_df_by_label(df, drop_label='-'):
    """
    drop observations with label 'drop_label'
    """
    return df.loc[df.label != drop_label]

# %%
snli_ori = pd.read_csv("data/{}/test.csv".format(data))
snli_ori = filter_df_by_label(snli_ori)
pre_process_nli_df(snli_ori)
snli_ori = snli_ori.reset_index(drop=True)

# %%
t = get_paired_t_statistic(df)
t
# Out:
# (9.951478598882094, 0.01603298213467705, 19647, 0.22582645540071822)

# %%
def e(alpha, n):
    return np.sqrt(np.log(2/alpha) / (2*n))

ids = df.loc[(df.A==0) & (df.B==1)]
ids = ids.index.tolist()

b = [224, 274, 697, 701, 1116, 1132,
     1283, 1293, 1663, 2080, 2145,
     2606, 3150, 4195, 4524, 4554, 453,
    4592, 4686, 4902, 4983, 5423, 6452,
    7217, 7993, 8195, 8457, 8859, 8866,
    9017, 9259, 9555, 9724, 10175, 10810,
    10838]

select = b[-1]

b_to_print = [] 
g = [i for i in ids[:ids.index(select)] if i not in b]
g_to_print = []


more = ids[ids.index(select):]

gn = len(g)
bn = len(b)
pct = gn/(gn+bn)

n = gn+bn 
# n = 200


e95 = lambda n: e(0.05, n)
x = np.array(range(1,n+1))

plt.plot(x, e95(x),color="blue");
p = np.random.uniform(0.5,1)
eps = e95(x)
n = eps.argmin()
e_id = eps[n]


print("n = {} | e_n = {:.1%}".format(x[n], e_id))


print(pct,"[",pct-e_id,",", pct+e_id, "]")
# Out:
# n = 200 | e_n = 9.6%
# 0.82 [ 0.7239677208680079 , 0.916032279131992 ]

# %%
ids = df.loc[(df.A==0) & (df.B==1)]
ids = ids.index.tolist()
n = len(ids)
pct = n/df.shape[0]
display(Markdown(r"### When $\rho=1.0$, the number of disrupted sentences (0 to 1) is {} ({:.1%} of the test data)".format(n,pct)))
comb = pd.concat([snli_ori, snli_trans.add_suffix("_2")],1)
# comb = comb.loc[ids]
comb = comb.loc[more]

display(HTML(comb.head(n).to_html()))
# display(HTML(comb.head(1).to_html()))
# Out:
# ### When $\rho=1.0$, the number of disrupted sentences (0 to 1) is 346 (1.8% of the test data)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>premise</th>
#       <th>hypothesis</th>
#       <th>label</th>
#       <th>premise_2</th>
#       <th>hypothesis_2</th>
#       <th>label_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>10838</th>
#       <td>in studies following children from infancy into childhood and adolescence early brief episodes of parental stimulation and sensitivity did not result in more competent children</td>
#       <td>parental stimulation and sensitivity towards a young child dont really affect a childs competency</td>
#       <td>entailment</td>
#       <td>in studies following child from babyhood into childhood and adolescence early legal brief episodes of parental stimulation and sensibility did not issue in more competent child</td>
#       <td>parental stimulation and sensibility towards a young kid dont really affect a childs competency</td>
#       <td>entailment</td>
#     </tr>
#     <tr>
#       <th>10914</th>
#       <td>ok i said so how do we do it</td>
#       <td>what need to be done</td>
#       <td>entailment</td>
#       <td>ok i state so how do we do it</td>
#       <td>what demand to be done</td>
#       <td>entailment</td>
#     </tr>
#     <tr>
#       <th>10935</th>
#       <td>the firm was stocking out of the low demand items which as described above suffered from relatively high demand variation</td>
#       <td>the firm quickly sold out of low demand items which was surprising because the demand for them had been consistently low</td>
#       <td>contradiction</td>
#       <td>the house was stocking out of the low demand point which as described above suffered from relatively high demand fluctuation</td>
#       <td>the house quickly sold out of low demand point which was surprising because the demand for them had be consistently low</td>
#       <td>contradiction</td>
#     </tr>
#     <tr>
#       <th>10979</th>
#       <td>the audubon nature centers are among the most serene and pristine places on earth</td>
#       <td>rubbish dumps have more diverse and beautiful ecosystems than audubon nature centers</td>
#       <td>contradiction</td>
#       <td>the audubon nature centers are among the most tranquil and pristine places on world</td>
#       <td>trash mopes have more divers and beautiful ecosystems than audubon nature centers</td>
#       <td>contradiction</td>
#     </tr>
#     <tr>
#       <th>11042</th>
#       <td>for more than a century the us federal and state governments have investigated sweatshops in the garment industry including the role of immigrants and have adopted legislation to ameliorate their impact on workers and consumers</td>
#       <td>the us government tries to shut down the sweatshops</td>
#       <td>neutral</td>
#       <td>for more than a century the us federal and province governments have investigated sweatshops in the garment industry including the part of immigrants and have adopted statute law to ameliorate their impact on workers and consumers</td>
#       <td>the us authorities effort to close down the sweatshops</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11087</th>
#       <td>by 833 it had reached its assigned cruising altitude of 31000 feet</td>
#       <td>by 833 it had followed its correct flight path</td>
#       <td>neutral</td>
#       <td>by 833 it had reached its assigned cruising height of 31000 feet</td>
#       <td>by 833 it had followed its right flight way</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11130</th>
#       <td>he could stand as a symbol of resistanceabove all resistance to the west and to america</td>
#       <td>he would have been a good symbol for them to follow</td>
#       <td>neutral</td>
#       <td>he could base as a symbol of resistanceabove all opposition to the west and to america</td>
#       <td>he would have be a good symbol for them to follow</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11160</th>
#       <td>levis uses proprietary software to make these modifications but other software systems are commercially available for modifying standard patterns and producing a marker to guide fabric cutting</td>
#       <td>levis have their own inhouse software for the purpose of customizing items</td>
#       <td>entailment</td>
#       <td>levis uses proprietary package to make these adjustment but other package systems are commercially available for modifying measure form and producing a marker to usher material cutting</td>
#       <td>levis have their own inhouse package for the design of customizing point</td>
#       <td>entailment</td>
#     </tr>
#     <tr>
#       <th>11219</th>
#       <td>\\ can you remember the very first stories that were read when you were little</td>
#       <td>did you write the first story that was read to you</td>
#       <td>neutral</td>
#       <td>\\ can you think the very first stories that were read when you were little</td>
#       <td>did you pen the first tale that was read to you</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11251</th>
#       <td>what how often</td>
#       <td>i dont mind how many times you did whatever</td>
#       <td>neutral</td>
#       <td>what how often</td>
#       <td>i dont head how many times you did whatever</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11278</th>
#       <td>the line to the white house shelter conference roomand the vice president kept cutting off</td>
#       <td>the line to the white house shelter conference room kept dropping calls</td>
#       <td>entailment</td>
#       <td>the line to the white house shelter conference roomand the frailty president hold cutting off</td>
#       <td>the line to the white house shelter conference room hold dropping calls</td>
#       <td>entailment</td>
#     </tr>
#     <tr>
#       <th>11404</th>
#       <td>it has been suggested that sf include only those stories which would be invalidated without their scientific content that fiction which concerns science scientists and the impact of science on humans that which explores alternate existences whether future extraterrestrial or only in characters minds based on facts and logical progression via scientific method</td>
#       <td>many science fiction stories are wholly unscientific and should instead be categorized as fantasy</td>
#       <td>neutral</td>
#       <td>it has be suggested that sf include only those stories which would be invalidated without their scientific content that fiction which concerns scientific discipline scientists and the impact of scientific discipline on man that which research replacement existences whether hereafter extraterrestrial or only in characters head based on facts and logical patterned advance via scientific method</td>
#       <td>many scientific discipline fiction stories are wholly unscientific and should instead be categorized as phantasy</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11450</th>
#       <td>the second chapter of the handbook is devoted in its entirety to the pronoun problem mercifully concluding with the expression of some doubt that an artificial generic pronoun like hir thon per and other abominations is likely to take hold</td>
#       <td>there are only two chapters n the entirety of the handbook</td>
#       <td>neutral</td>
#       <td>the second chapter of the enchiridion is devoted in its totality to the pronoun job mercifully concluding with the face of some uncertainty that an unreal generic wine pronoun like hir thon per and other abominations is likely to take grip</td>
#       <td>there are only two chapters nitrogen the totality of the enchiridion</td>
#       <td>neutral</td>
#     </tr>
#     <tr>
#       <th>11482</th>
#       <td>it is difficult for the nonspecialist reader like me to assess the validity of his arguments which are based on his contention that the language and its congeners were carried along by the spread of nomad pastoralism</td>
#       <td>its clear to me that his arguments make no sense</td>
#       <td>neutral</td>
#       <td>it is difficult for the nonspecialist reader like me to seat the rigor of his

# %% [markdown]
# ## What are the most commom transformations that appear on the error pairs?

# %%
spaces = re.compile(' +')
results = []

comb = pd.concat([snli_ori, snli_trans.add_suffix("_2")],1)
ids = comb.index.tolist()
for id_ in ids:
    s = comb.loc[id_].premise + " " + comb.loc[id_].hypothesis
    st = comb.loc[id_].premise_2 + " " + comb.loc[id_].hypothesis_2
    s = spaces.sub(" ",s)
    st = spaces.sub(" ",st)
    s = s.strip()
    st = st.strip()
    s = set(s.split(" "))
    st = set(st.split(" "))
    diff = list(s - st)
    try:
        diff = list(map(f, diff))
        results += diff
    except KeyError:
        pass
#         print(id_)
#         print(s)
#         print(st)
    
    
    
results_c = Counter(results)
dict_id = [i[0] for i in results_c.most_common(10)]
sin_noun.loc[:, "freq"] = [results_c[i]/len(results) for i in sin_noun.index]
sin_noun = sin_noun.sort_values("freq", ascending=False)
sin_noun.loc[:, "freq"] = sin_noun.freq.map(lambda x: "{:.1%}".format(x))
sin_noun.head(10)
# Out:
#                key    value  freq
# 944           been       be  1.7%
# 340           also      too  1.0%
# 8941          said    state  0.9%
# 4970          help      aid  0.8%
# 1770      children    child  0.7%
# 6200          made       do  0.7%
# 11426         year       yr  0.7%
# 6862          need   demand  0.7%
# 948         before  earlier  0.6%
# 5435   information     info  0.6%
